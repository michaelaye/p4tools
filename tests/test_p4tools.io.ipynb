# %%
from p4tools import io

# %%
io.get_blotch_catalog()
# Out:
#        marking_id   angle     tile_id  image_x   image_y  n_votes  \
# 0         B000000    2.28  APF0000cia  3330.27   5573.00        4
# 1         B000001    1.38  APF0000cia  3593.60   5706.40        5
# 2         B000004    7.16  APF0000cic    98.10  34394.70       10
# 3         B000005   81.00  APF0000cic   825.58  34203.38        8
# 4         B000006   14.66  APF0000cic   152.67  34155.33        3
# ...           ...     ...         ...      ...       ...      ...
# 249796    B044be7    0.00  APF0000idg  1276.20  14257.20        5
# 249797    B044be8    0.00  APF0000idg  1311.25  14345.75        4
# 249798    B044be9    0.00  APF0000idg  1266.00  14355.25        4
# 249799    B044bea  168.67  APF0000idh    74.07    148.86        7
# 249800    B044beb  172.85  APF0000idh   265.00     98.33        3
#
#                   obsid  radius_1  radius_2  vote_ratio  ...  y_angle  \
# 0       ESP_012079_0945     22.13     15.78        1.00  ...     0.10
# ...

# %%
io.get_fan_catalog()
# Out:
#        marking_id   angle  distance     tile_id  image_x   image_y  n_votes  \
# 0         F000000  205.56    179.71  APF0000ci9  2270.76  24336.16       35
# 1         F000001  185.39    179.62  APF0000cia  3391.21   5640.60       15
# 2         F000002  184.98    500.27  APF0000cia  3509.96   5876.70       10
# 3         F000004  184.29    105.43  APF0000cia  3716.27   5824.50        6
# 4         F000005  189.42    109.50  APF0000cia  3452.17   6033.00        3
# ...           ...     ...       ...         ...      ...       ...      ...
# 158471    F02bc86   87.64     87.78  APF0000lzw  1120.29  14752.23       23
# 158472    F02bc87   64.02     91.47  APF0000lzw  1474.27  14764.35       21
# 158473    F02bc89   62.42     68.26  APF0000lzw  1071.98  14821.38       14
# 158474    F02bc8a   53.25    100.43  APF0000lzw  1478.67  14839.67        6
# 158475    F02bc8b  111.03     93.02  APF0000q5w   757.50  13341.33        3
#
# ...

# %%
config = io.get_config()

# %%
root = io.get_data_root()

# %%
tid = 'APF0000tld'

# %%
io.get_fans_for_tile(tid)
# Out:
#       marking_id   angle  distance     tile_id  image_x   image_y  n_votes  \
# 92197    F019802  198.90    150.30  APF0000tld  1136.65  19247.23       15
# 92198    F019803  200.62     57.30  APF0000tld  1002.62  19342.12       18
# 92199    F019804  200.83    144.01  APF0000tld  1353.63  19439.44       24
# 92200    F019805  196.52     40.93  APF0000tld  1407.57  19522.45        8
# 92201    F019806  199.04     94.72  APF0000tld  1422.20  19558.77       14
# 92202    F019807  198.57     59.21  APF0000tld  1387.58  19561.28        7
# 92203    F019808  200.42    192.60  APF0000tld  1134.45  19579.06       14
# 92204    F019809  203.17     32.86  APF0000tld  1018.08  19576.01        4
# 92205    F01980a  202.18     45.26  APF0000tld   802.76  19495.40        3
# 92206    F01980b  200.41     83.31  APF0000tld   861.25  19512.88        7
# 92207    F01980c  199.69     87.88  APF0000tld   808.23  19571.81       15
# ...

# %%
io.get_meta_data()
# Out:
#       OBSERVATION_ID  IMAGE_CENTER_LATITUDE  IMAGE_CENTER_LONGITUDE  \
# 0    ESP_011296_0975               -82.1965                225.2530
# 1    ESP_011341_0980               -81.7969                 76.1304
# 2    ESP_011348_0950               -85.0427                259.0940
# 3    ESP_011350_0945               -85.2160                181.4150
# 4    ESP_011351_0945               -85.2157                181.5480
# ..               ...                    ...                     ...
# 216  ESP_022273_0950               -84.8184                 65.7963
# 217  ESP_022339_0935               -86.2751                 99.6123
# 218  ESP_022379_0930               -87.0045                 86.5510
# 219  ESP_022510_0980               -81.6988                 66.3188
# 220  ESP_022699_0985               -81.4043                295.7820
#
#      SOLAR_LONGITUDE           START_TIME  map_scale  north_azimuth  \
# 0            178.833  2008-12-23 16:15:26       1.00     110.600107
# ...

# %%
io.get_region_names()
# Out:
#                obsid  lat_IND  lon_IND      roi_name  minimal_distance  \
# 0    ESP_012079_0945 -85.4074  103.970  Macclesfield          0.944588
# 1    ESP_021494_0945 -85.4041  103.943  Macclesfield          0.511133
# 2    ESP_011407_0945 -85.4065  103.983  Macclesfield          0.957066
# 3    ESP_020782_0945 -85.4071  103.967  Macclesfield          0.901696
# 4    ESP_020716_0945 -85.4086  103.979  Macclesfield          1.098928
# ..               ...      ...      ...           ...               ...
# 449  ESP_029762_0940 -85.7567  106.026    Manhattan2          0.782410
# 450  ESP_037977_0940 -85.6793  105.614    Manhattan2          8.544184
# 451  ESP_037976_0940 -85.6694  105.903    Manhattan2          9.131402
# 452  ESP_040311_0940 -85.7806  106.025    Manhattan2          3.335817
# 453  ESP_040193_0940 -85.7860  106.143    Manhattan2          4.158145
#
#      lat_WORD  lon_WORD                 time  MY
# 0     -85.401   103.901  2009-02-22 16:32:19  29
# ...

# %%
io.get_subframe_by_tile_id(tid)
# Out:
# array([[[198, 187, 183],
#         [137, 126, 122],
#         [129, 118, 112],
#         ...,
#         [150, 133, 125],
#         [145, 130, 123],
#         [151, 136, 129]],
#
#        [[171, 160, 156],
#         [133, 122, 116],
#         [138, 127, 121],
#         ...,
#         [139, 122, 114],
#         [137, 122, 115],
#         [133, 118, 111]],
#
#        [[159, 148, 142],
#         [148, 137, 131],
#         [158, 147, 141],
#         ...,
#         [130, 115, 108],
#         [136, 123, 117],
#         [133, 120, 114]],
#
#        ...,
#
#        [[255, 253, 244],
#         [255, 251, 242],
#         [255, 254, 246],
#         ...,
#         [226, 208, 194],
#         [217, 199, 187],
#         [229, 211, 199]],
#
#        [[255, 255, 250],
#         [255, 255, 250],
#         [255, 254, 250],
#         ...,
#         [243, 225, 213],
#         [223, 207, 194],
#         [239, 221, 209]],
#
#        [[255, 255, 251],
#         [249, 248, 244],
#         [208, 204, 201],
# ...
