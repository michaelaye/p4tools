# %%
from p4tools import io
from p4tools import markings as m

# %%
ftid = "APF0000tld"
btid = "APF00006tp"

# %%
blotches = io.get_blotches_for_tile(btid)

# %%
blotches
# Out:
#      marking_id   angle     tile_id  image_x   image_y  n_votes  \
# 4585    B001520   17.25  APF00006tp  3713.30  28386.40       10
# 4586    B001521   25.39  APF00006tp  3672.67  28231.22        9
# 4587    B001522  179.99  APF00006tp  3702.40  28076.30       10
# 4588    B001523    8.85  APF00006tp  3482.78  28416.78        9
# 4589    B001524   26.99  APF00006tp  3138.44  27964.50        8
# 4590    B001525  155.75  APF00006tp  3157.38  28307.25        4
# 4591    B001526   13.88  APF00006tp  3100.62  28296.00        4
# 4592    B001527   10.74  APF00006tp  3697.58  28547.00        6
# 4593    B001528  121.49  APF00006tp  2970.21  28519.14        7
# 4594    B001529    4.50  APF00006tp  3431.10  27955.60        5
# 4595    B00152a  171.92  APF00006tp  3298.67  28146.67        3
# 4596    B00152b   13.17  APF00006tp  3323.62  28271.50        8
# 4597    B00152c  165.93  APF00006tp  3249.33  28473.33        3
# 4598    B00152d    1.94  APF00006tp  3733.70  27970.60        5
# ...

# %%
b = m.Blotch(blotches.iloc[0])

# %%
b.plot()
# Out:
# 100%|████████████████████████████████████████| 181k/181k [00:00<00:00, 683MB/s]

# %%
tb = m.TileBlotches(btid)

# %%
tb.plot()
